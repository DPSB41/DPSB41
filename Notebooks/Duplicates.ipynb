# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
pd.set_option('display.float_format', lambda x: '%.0f' % x)

# %%
try:
    engine = create_engine("mysql+pymysql://root:a21305556699@localhost:3306/DPSB", echo=False)
    query = "SELECT * FROM ARTICLES"
    df = pd.read_sql(query, engine)
except Exception as e:
    engine.close()
    print(str(e))
df
# Out:
#       ARTICLE                                        DESCRITPION  CHAPITRE  \
# 0           1                               Etudes et maturation       147
# 1           2                                 Création nouvelles       147
# 2           3                                         Extensions       147
# 3           8                                             Autres       147
# 4           9                                     Renouvellement       147
# ...       ...                                                ...       ...
# 1387        6  Réalisation et équipement de cantines scolaire...       691
# 1388        7  Chauffage / climatisation scolaire au profit d...       691
# 1389        8  Acquisition de scolaire au profit des zones d'...       691
# 1390        1                                   Etudes générales       111
# 1391        1                             Electrification rurale       125
#
#               OBSERVATION
# 0                    None
# 1                    None
# 2                    None
# 3                    None
# 4                    None
# ...                   ...
# 1387                 None
# 1388                 None
# 1389                 None
# 1390                 None
# 1391  Décis du04/08/2 002
#
# [1392 rows x 4 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df.reset_index()
# Out:
#      index  ARTICLE                                        DESCRITPION  \
# 0        0        1                               Etudes et maturation
# 1        1        2                                 Création nouvelles
# 2        2        3                                         Extensions
# 3        3        8                                             Autres
# 4        4        9                                     Renouvellement
# ..     ...      ...                                                ...
# 700   1387        6  Réalisation et équipement de cantines scolaire...
# 701   1388        7  Chauffage / climatisation scolaire au profit d...
# 702   1389        8  Acquisition de scolaire au profit des zones d'...
# 703   1390        1                                   Etudes générales
# 704   1391        1                             Electrification rurale
#
#      CHAPITRE          OBSERVATION
# 0         147                 None
# 1         147                 None
# 2         147                 None
# 3         147                 None
# 4         147                 None
# ..        ...                  ...
# 700       691                 None
# 701       691                 None
# 702       691                 None
# 703       111                 None
# 704       125  Décis du04/08/2 002
#
# [705 rows x 5 columns]

# %%
df.drop(columns="CODE", inplace=True)
# Out:
#       ARTICLE                                        DESCRITPION  CHAPITRE  \
# 0           1                               Etudes et maturation       147
# 1           2                                 Création nouvelles       147
# 2           3                                         Extensions       147
# 3           8                                             Autres       147
# 4           9                                     Renouvellement       147
# ...       ...                                                ...       ...
# 1387        6  Réalisation et équipement de cantines scolaire...       691
# 1388        7  Chauffage / climatisation scolaire au profit d...       691
# 1389        8  Acquisition de scolaire au profit des zones d'...       691
# 1390        1                                   Etudes générales       111
# 1391        1                             Electrification rurale       125
#
#               OBSERVATION
# 0                    None
# 1                    None
# 2                    None
# 3                    None
# 4                    None
# ...                   ...
# 1387                 None
# 1388                 None
# 1389                 None
# 1390                 None
# 1391  Décis du04/08/2 002
#
# [705 rows x 4 columns]

# %%
df.to_excel("/home/zuhir/Documents/ARTICLES.xlsx")
